# %%
import pandas as pd

# Read the Excel file
df = pd.read_excel('bestfit.xlsx')

# Select the first four columns
df = df.iloc[:, :4]

df
# Out:
#     test_nb  V_requested  V_measured  Pulse_nb
# 0         1         0.10     0.07973       439
# 1         2         0.10     0.07574       438
# 2         3         0.10     0.08219       438
# 3         4         0.10     0.07388       438
# 4         5         0.10     0.07490       438
# 5         6         0.25     0.18764      1096
# 6         7         0.25     0.21010      1095
# 7         8         0.25     0.19549      1095
# 8         9         0.50     0.35089      2191
# 9        10         0.50     0.35989      2190
# 10       11         0.50     0.36966      2190
# 11       12         0.75     0.58082      3286
# 12       13         0.75     0.59491      3285
# 13       14         0.75     0.57491      3285
# 14       15         1.00     0.85232      4380
# 15       16         1.00     0.80777      4380
# 16       17         1.00     0.79422      4380
# 17       18         1.25     0.97041      5475
# 18       19         1.25     0.99820      5475
# 19       20         1.25     1.11110      5475

# %%
import numpy as np
import matplotlib.pyplot as plt
# Assuming you have two arrays x and y
x = np.array(df['Pulse_nb'])
y = np.array(df['V_measured'])

# Calculate coefficients of the line of best fit
coefficients = np.polyfit(x, y, 1)
# The first element of the array is the slope (m), and the second element is the y-intercept (c)
slope, intercept = coefficients

from fractions import Fraction

# Convert a float to a fraction
frac = Fraction.from_float(slope)

print(frac)

print(f'Slope (m): {slope}')
print(f'Y-intercept (c): {intercept}')
# Create a polynomial function with these coefficients
polynomial = np.poly1d(coefficients)

# Generate y-values for the line of best fit
y_fit = polynomial(x)

# Plot the data points
plt.scatter(x, y)

# Plot the line of best fit
plt.plot(x, y_fit, color='red')

plt.show()
# Out:
# 1737395687308229/9223372036854775808
# Slope (m): 0.0001883688178646528
# Y-intercept (c): -0.017519234333790882
